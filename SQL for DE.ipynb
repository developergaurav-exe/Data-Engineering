# %% [markdown]
# ### SQL for Data Engg

# %% [markdown]
# #### Application Architecture and RDBMS
# ![image.png](attachment:image.png)

# %%
'''
Different DATABASE TECHNOLOGIES

RDBMS Technologies (Application Type Technologies)
- Oracle
- Snowflake
- Sybase (SAP)
- Postgres (Most Preffered)
- MySQL (Open Source)
- MS SQL Server  

For Analytics Type Technologies (Data Warehousing or MPP(Massively Parallel Processing))
- GCP BigQuery
- AWS Redshift
- Azure Synapse
- Snowflake
- Teradata
- Databricks

NoSQL Databases
- MongoDB
- Cassandra 

Search
- Elastic Search
- SolR

Graph
- Neo4j
'''

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
#
# #### Abbreviations
# - OLTP: Online Transaction Process
# - OLAP: Online Analytical Process
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# - DSS: Decsion Support Systems
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Overview of Postgres Database Server and pgAdmin
# ![image.png](attachment:image.png)
